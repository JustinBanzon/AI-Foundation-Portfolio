# %%
import numpy as np

# %%
def neuron_output(inputs,weights,bias):
    result = bias
    for i in range(len(inputs)):
        result += inputs[i] * weights[i]
    return result
inputs = [1,2,3,2.5]
print("inputs:",inputs)
weights = [0.2,0.8,-0.5,1]
print("weights:",weights)
bias = 2
print("bias:",bias)
neuron_result = neuron_output(inputs,weights,bias)
print("Neuron output:",neuron_result)
# Out:
# inputs: [1, 2, 3, 2.5]
# weights: [0.2, 0.8, -0.5, 1]
# bias: 2
# Neuron output: 4.800000000000001

# %%
#Multiple Neurons
import numpy as np

test_input = [1,2,3,2.5]
print("inputs:",test_input)
test_layer_weights = [[0.2,0.8,-0.5,1], [0.5,-0.91,0.26,-0.5], [-0.26,-0.27,0.17,0.87]]
print("weights:\n neuron 1:",test_layer_weights[0],"\n neuron 2:",test_layer_weights[1],"\n neuron 3:",test_layer_weights[2])
test_layer_biases = [2,3,0.5]
print("bias:\n neuron 1:",test_layer_biases[0],"\n neuron 2:",test_layer_biases[1],"\n neuron 3:",test_layer_biases[2])
test_layer = np.dot(test_layer_weights,test_input)+test_layer_biases
print(test_layer)
# Out:
# inputs: [1, 2, 3, 2.5]
# weights:
#  neuron 1: [0.2, 0.8, -0.5, 1]
#  neuron 2: [0.5, -0.91, 0.26, -0.5]
#  neuron 3: [-0.26, -0.27, 0.17, 0.87]
# bias:
#  neuron 1: 2
#  neuron 2: 3
#  neuron 3: 0.5
# [4.8   1.21  2.385]

# %%
#Input Batches
batch_input = np.array([[1,2,3,2.5],
              [2.0,5.0,-1.0,2.0],
              [-1.5,2.7,3.3,-0.8]])
print("inputs:",batch_input)
batch_weights = np.array([[0.2,0.8,-0.5,1], [0.5,-0.91,0.26,-0.5], [-0.26,-0.27,0.17,0.87]])
print("weights:\n neuron 1:",batch_weights[0],"\n neuron 2:",batch_weights[1],"\n neuron 3:",batch_weights[2])
batch_biases = [2,3,0.5]
print("bias:\n neuron 1:",batch_biases[0],"\n neuron 2:",batch_biases[1],"\n neuron 3:",batch_biases[2])
batch_layer_1 = np.dot(batch_input,batch_weights.T)+batch_biases
print(batch_layer_1)
# Out:
# inputs: [[ 1.   2.   3.   2.5]
#  [ 2.   5.  -1.   2. ]
#  [-1.5  2.7  3.3 -0.8]]
# weights:
#  neuron 1: [ 0.2  0.8 -0.5  1. ]
#  neuron 2: [ 0.5  -0.91  0.26 -0.5 ]
#  neuron 3: [-0.26 -0.27  0.17  0.87]
# bias:
#  neuron 1: 2
#  neuron 2: 3
#  neuron 3: 0.5
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %%
#second layer
batch_weights2 = np.array([[0.1,-0.14,0.5], [-0.5,0.12,-0.33], [-0.44,0.73,-0.13]])
print("layer 2\nweights:\n neuron 1:",batch_weights2[0],"\n neuron 2:",batch_weights2[1],"\n neuron 3:",batch_weights2[2])
batch_biases2 = [-1,2,-0.5]
print("bias:\n neuron 1:",batch_biases2[0],"\n neuron 2:",batch_biases2[1],"\n neuron 3:",batch_biases2[2])
batch_layer_2 = np.dot(batch_layer_1,batch_weights2.T)+batch_biases2
print(batch_layer_2)
# Out:
# layer 2
# weights:
#  neuron 1: [ 0.1  -0.14  0.5 ]
#  neuron 2: [-0.5   0.12 -0.33]
#  neuron 3: [-0.44  0.73 -0.13]
# bias:
#  neuron 1: -1
#  neuron 2: 2
#  neuron 3: -0.5
# [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %%
#Object Layers
np.random.seed(0)

X = np.array([[1,2,3,2.5], [2.0,5.0,-1.0,2.0], [-1.5,2.7,3.3,-0.8]])
class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = 0.10 * np.random.randn(n_inputs,n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
layer1 = LayerDense(4,5)
layer2 = LayerDense(5,2)
layer1.forward(X)
print(layer1.output)
layer2.forward(layer1.output)
print(layer2.output)
# Out:
# [[ 0.10758131  1.03983522  0.24462411  0.31821498  0.18851053]
#  [-0.08349796  0.70846411  0.00293357  0.44701525  0.36360538]
#  [-0.50763245  0.55688422  0.07987797 -0.34889573  0.04553042]]
# [[ 0.148296   -0.08397602]
#  [ 0.14100315 -0.01340469]
#  [ 0.20124979 -0.07290616]]

# %%
#Rectified lienar function:
inputs = [0,2,-1,3.3,-2.7,1.1,2.2,-100]
outputs = []
for i in inputs:
    if i > 0:
        outputs.append(i)
    else:
        outputs.append(0)
print(outputs)
# Out:
# [0, 2, 0, 3.3, 0, 1.1, 2.2, 0]

# %%
#Rectified linear function
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
np.random.seed(0)

X = np.array([[1,2,3,2.5], [2.0,5.0,-1.0,2.0], [-1.5,2.7,3.3,-0.8]])
class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = 0.10 * np.random.randn(n_inputs,n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
class Activation_ReLU:
    def forward(self, inputs):
        self.output = np.maximum(0,inputs)
layer1 = LayerDense(4,5)
activation1 = Activation_ReLU()
layer1.forward(X)
#print(layer1.output)
activation1.forward(layer1.output)
print(activation1.output)
# Out:
# [[0.10758132 1.0398352  0.2446241  0.31821495 0.18851054]
#  [0.         0.70846415 0.00293357 0.44701523 0.3636054 ]
#  [0.         0.5568842  0.07987796 0.         0.04553042]]

# %%
#Softmax
import numpy as np
import nnfs
nnfs.init()
layer_outputs = [[4.8,1.21,2.385],
                [8.9,-1.81,0.2],
                [1.41,1.051,0.026]]

exp_values = np.exp(layer_outputs)

print(np.sum(layer_outputs, axis = 1))
norm_values = exp_values/np.sum(exp_values, axis = 1, keepdims = True)
print(norm_values)
#print(sum(norm_values))
# Out:
# [8.395 7.29  2.487]
# [[8.95282664e-01 2.47083068e-02 8.00090293e-02]
#  [9.99811129e-01 2.23163963e-05 1.66554348e-04]
#  [5.13097164e-01 3.58333899e-01 1.28568936e-01]]

# %%
lim = 0
i = 0
while (np.exp(i)<float('inf')):
    lim = i
    i += 1
print(lim)
np.exp(lim)
# Out:
# 709
# C:\Users\banzoj\AppData\Local\Temp\ipykernel_13908\800185346.py:3: RuntimeWarning: overflow encountered in exp
#   while (np.exp(i)<float('inf')):
# np.float64(8.218407461554972e+307)

# %%
#Softmax + Rectified Linear functions
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
np.random.seed(0)

X = np.array([[1,2,3,2.5], [2.0,5.0,-1.0,2.0], [-1.5,2.7,3.3,-0.8]])
class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = 0.10 * np.random.randn(n_inputs,n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
class ActivationReLU:
    def forward(self, inputs):
        self.output = np.maximum(0,inputs)
class ActivationSoftmax:
    def forward(self,inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1,keepdims=True))
        probabilities = exp_values/np.sum(exp_values, axis = 1, keepdims = True)
        self.output = probabilities
X,y = spiral_data(samples=100,classes=3)
dense1 = LayerDense(2,3)
activation1 = ActivationReLU()

dense2 = LayerDense(3,3)
activation2 = ActivationSoftmax()
dense1.forward(X)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
print(activation2.output[:10])
# Out:
# [[0.33333333 0.33333333 0.33333333]
#  [0.33331734 0.33331832 0.33336434]
#  [0.3332888  0.33329153 0.33341967]
#  [0.33325941 0.33326395 0.33347665]
#  [0.33323311 0.33323926 0.33352763]
#  [0.33328417 0.33328719 0.33342864]
#  [0.33318217 0.33319145 0.33362638]
#  [0.33318279 0.33319203 0.33362518]
#  [0.33314924 0.33316055 0.33369021]
#  [0.33310588 0.33311984 0.33377428]]

# %%
#calculating loss

#One-hot encoding: n classes, vector has 0 in all but one position, which has a 1 instead
import numpy as np
from math import e
b = 5.2
logB = np.log(b)
print(logB)
print(e**logB)
# Out:
# 1.6486586255873816
# 5.199999999999999

# %%
#Categorical Cross-entropy
import math
from math import e
softmax_output = [0.7,0.1,0.2]
target_output = [1,0,0]
loss = 0
for i in range(len(softmax_output)):
    loss -= target_output[i] * math.log(softmax_output[i])
print(loss)
print(-math.log(0.7))
print(-math.log(0.5))
# Out:
# 0.35667494393873245
# 0.35667494393873245
# 0.6931471805599453

# %%
import numpy as np
softmax_outputs = np.array([[0.0,0.1,0.2],[0.1,0.5,0.4],[0.02,0.9,0.08]])
class_targets = [0,1,1]
neg_log = -np.log(softmax_outputs[range(len(softmax_outputs)),class_targets])
neg_log_clipped = np.clip(neg_log,1e-15,1-1e-15)
avg_loss = np.mean(neg_log_clipped)
print(avg_loss)
# Out:
# 0.5995025654059235
# C:\Users\banzoj\AppData\Local\Temp\ipykernel_2548\351087815.py:4: RuntimeWarning: divide by zero encountered in log
#   neg_log = -np.log(softmax_outputs[range(len(softmax_outputs)),class_targets])

# %%
#Loss + Softmax + Rectified Linear functions
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
np.random.seed(0)

X = np.array([[1,2,3,2.5], [2.0,5.0,-1.0,2.0], [-1.5,2.7,3.3,-0.8]])
class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = 0.10 * np.random.randn(n_inputs,n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
class ActivationReLU:
    def forward(self, inputs):
        self.output = np.maximum(0,inputs)
class ActivationSoftmax:
    def forward(self,inputs):
        exp_values = np.exp(inputs - np.max(inputs, axis=1,keepdims=True))
        probabilities = exp_values/np.sum(exp_values, axis = 1, keepdims = True)
        self.output = probabilities
class Loss:
    def calculate(self, output, y):
        sample_losses = self.forward(output,y)
        data_loss = np.mean(sample_losses)
        return data_loss
class Loss_CatecoricalCrossEntropy(Loss):
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clipped = np.clip(y_pred,1e-15,1-1e-15)
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples),y_true]
        elif len(y_true.shape == 2):
            correct_confidences = np.sum(y_pred_clipped*y_true, axis=1)
        negative_log_likeliehoods = -np.log(correct_confidences)
        return negative_log_likeliehoods
X,y = spiral_data(samples=100,classes=3)
dense1 = LayerDense(2,3)
activation1 = ActivationReLU()

dense2 = LayerDense(3,3)
activation2 = ActivationSoftmax()
dense1.forward(X)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
print(activation2.output[:10])
loss_function = Loss_CatecoricalCrossEntropy()
loss = loss_function.calculate(activation2.output,y)
print("Loss:",loss)
# Out:
# [[0.33333333 0.33333333 0.33333333]
#  [0.33331734 0.33331832 0.33336434]
#  [0.3332888  0.33329153 0.33341967]
#  [0.33325941 0.33326395 0.33347665]
#  [0.33323311 0.33323926 0.33352763]
#  [0.33328417 0.33328719 0.33342864]
#  [0.33318217 0.33319145 0.33362638]
#  [0.33318279 0.33319203 0.33362518]
#  [0.33314924 0.33316055 0.33369021]
#  [0.33310588 0.33311984 0.33377428]]
# Loss: 1.0984449588022467

# %%
import matplotlib.pyplot as plt
import numpy as np
import nnfs
from nnfs.datasets import vertical_data
nnfs.init()

class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = np.random.randn(n_inputs,n_neurons) * np.sqrt(2 / n_inputs)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
class ActivationReLU:
    def forward(self, inputs):
        self.output = np.maximum(0,inputs)
relu = lambda inputs:np.maximum(0,inputs)
class ActivationSoftmax:
    def forward(self,inputs):
        exp_values = np.exp(inputs - inputs.max(axis=1,keepdims=True))
        probabilities = exp_values/exp_values.sum(axis = 1, keepdims = True)
        self.output = probabilities
def softmax(inputs):
    exp_values = np.exp(inputs - inputs.max(axis=1,keepdims=True))
    probabilities = exp_values/exp_values.sum(axis = 1, keepdims = True)
    return probabilities
class Loss:
    def calculate(self, output, y):
        sample_losses = self.forward(output,y)
        data_loss = np.mean(sample_losses)
        return data_loss
class Loss_CatecoricalCrossEntropy(Loss):
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clipped = np.clip(y_pred,1e-15,1-1e-15)
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples),y_true]
        elif len(y_true.shape == 2):
            correct_confidences = np.sum(y_pred_clipped*y_true, axis=1)
        negative_log_likeliehoods = -np.log(correct_confidences)
        return negative_log_likeliehoods

X, y = vertical_data(samples=450,classes=3)
D = X.shape[1]
H = 3

dense1 = LayerDense(D,H)
activation1 = ActivationReLU()
dense2 = LayerDense(H,3)
activation2 = ActivationSoftmax()

print(dense1.weights.shape,dense1.biases.shape,dense2.weights.shape,dense2.biases.shape)
loss_function = Loss_CatecoricalCrossEntropy()

lowest_loss = float("inf")
best_dense1_weights = dense1.weights.copy()
best_dense1_biases = dense1.biases.copy()
best_dense2_weights = dense2.weights.copy()
best_dense2_biases = dense2.biases.copy()

lr = 0.05
epochs = 500
batch = 64
losses = []
accuracies = []
for _ in range(epochs):
    idx = np.random.permutation(len(X))
    Xs, Ys = X[idx], y[idx]
    for i in range(0, len(Xs), batch):
        xb = Xs[i:i + batch]
        yb = Ys[i:i + batch]
        z1 = xb.dot(dense1.weights) + dense1.biases
        a1 = relu(z1)
        logits = a1.dot(dense2.weights) + dense2.biases
        probs = softmax(logits)
        Yb = np.zeros_like(probs)
        Yb[np.arange(len(yb)), yb] = 1
        dlog = (probs - Yb) / len(yb)
        dW2 = a1.T.dot(dlog)
        db2 = dlog.sum(axis=0)
        da1 = dlog.dot(dense2.weights.T)
        dz1 = da1 * (z1 > 0)
        dW1 = xb.T.dot(dz1)
        db1 = dz1.sum(axis=0)
        dense2.weights -= lr * dW2
        dense2.biases -= lr * db2
        dense1.weights -= lr * dW1
        dense1.biases -= lr * db1

    dense1.forward(X)
    activation1.forward(dense1.output)
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)
    
    loss = loss_function.calculate(activation2.output,y)
    losses.append(loss)
    
    predictions = np.argmax(activation2.output, axis=1)
    accuracy = np.mean(predictions==y)
    accuracies.append(accuracy)
    if loss < lowest_loss:
        #print("New set of weights found, iteration:",iteration,"loss:",loss,"acc:",accuracy)
        best_dense1_weights = dense1.weights.copy()
        best_dense1_biases = dense1.biases.copy()
        best_dense2_weights = dense2.weights.copy()
        best_dense2_biases = dense2.biases.copy()
        lowest_loss = loss
    else:
        dense1.weights = best_dense1_weights.copy()
        dense1.biases = best_dense1_biases.copy()
        dense2.weights = best_dense2_weights.copy()
        dense2.biases = best_dense2_biases.copy()
plt.figure()
plt.plot(losses, color="red")
plt.plot(accuracies, color="green")
plt.title("Neural Network — Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Accuracy"])
plt.grid(True)
plt.show()

test_X, test_y = vertical_data(samples=450,classes=3)
xx, yy = np.meshgrid(
    np.linspace(test_X[:, 0].min() - 1, test_X[:, 0].max() + 1, 300),
    np.linspace(test_X[:, 1].min() - 1, test_X[:, 1].max() + 1, 300)
)
grid = np.c_[xx.ravel(), yy.ravel()]
dense1.forward(grid)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
activation_array = np.array(activation2.output)
pred = np.argmax(activation_array,axis=1).reshape(xx.shape)
plt.figure()
plt.contourf(xx, yy, pred, 3)
plt.scatter(test_X[:, 0], test_X[:, 1], c=test_y, edgecolor="black")
plt.title("Neural Network — Decision Regions")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
# Out:
# (2, 3) (1, 3) (3, 3) (1, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

class LayerDense:
    def __init__(self,n_inputs,n_neurons):
        self.weights = np.random.randn(n_inputs,n_neurons) * np.sqrt(2 / n_inputs)
        self.biases = np.zeros((1,n_neurons))
    def forward(self,inputs):
        self.output = np.dot(inputs,self.weights) + self.biases
relu = lambda inputs:np.maximum(0,inputs)
class ActivationReLU:
    def forward(self, inputs):
        self.output = relu(inputs)
def softmax(inputs):
    exp_values = np.exp(inputs - inputs.max(axis=1,keepdims=True))
    probabilities = exp_values/exp_values.sum(axis = 1, keepdims = True)
    return probabilities
class ActivationSoftmax:
    def forward(self,inputs):
        self.output = softmax(inputs)
class Loss:
    def calculate(self, output, y):
        sample_losses = self.forward(output,y)
        data_loss = np.mean(sample_losses)
        return data_loss
class Loss_CatecoricalCrossEntropy(Loss):
    def forward(self, y_pred, y_true):
        samples = len(y_pred)
        y_pred_clipped = np.clip(y_pred,1e-15,1-1e-15)
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples),y_true]
        elif len(y_true.shape == 2):
            correct_confidences = np.sum(y_pred_clipped*y_true, axis=1)
        negative_log_likeliehoods = -np.log(correct_confidences)
        return negative_log_likeliehoods

X, y = spiral_data(samples=450,classes=3)
D = X.shape[1]
H = 32

dense_in = LayerDense(D,H)
activation_in = ActivationReLU()
dense_hidden1 = LayerDense(H,H)
activation_hidden1 = ActivationReLU()
dense_hidden2 = LayerDense(H,H)
activation_hidden2 = ActivationReLU()
dense_out = LayerDense(H,3)
activation_out = ActivationSoftmax()

print(dense_in.weights.shape,dense_in.biases.shape,dense_out.weights.shape,dense_out.biases.shape)
loss_function = Loss_CatecoricalCrossEntropy()

lr = 0.05
epochs = 500
batch = 64
losses = []
accuracies = []
for _ in range(epochs):
    idx = np.random.permutation(len(X))
    Xs, Ys = X[idx], y[idx]
    for i in range(0, len(Xs), batch):
        xb = Xs[i:i + batch]
        yb = Ys[i:i + batch]
        z1 = xb.dot(dense_in.weights) + dense_in.biases
        a1 = relu(z1)
        z2 = a1.dot(dense_hidden1.weights) + dense_hidden1.biases
        a2 = relu(z2)
        z3 = a2.dot(dense_hidden2.weights) + dense_hidden2.biases
        a3 = relu(z3)
        logits = a3.dot(dense_out.weights) + dense_out.biases
        probs = softmax(logits)
        Yb = np.zeros_like(probs)
        Yb[np.arange(len(yb)), yb] = 1
        dlog = (probs - Yb) / len(yb)
        dW4 = a3.T.dot(dlog)
        db4 = dlog.sum(axis=0)
        da3 = dlog.dot(dense_out.weights.T)
        dz3 = da3 * (z3 > 0)
        dW3 = a2.T.dot(dz3)
        db3 = dz3.sum(axis=0)
        da2 = da3.dot(dense_hidden2.weights.T)
        dz2 = da2 * (z2 > 0)
        dW2 = a1.T.dot(dz2)
        db2 = dz2.sum(axis=0)
        da1 = da2.dot(dense_hidden1.weights.T)
        dz1 = da1 * (z1 > 0)
        dW1 = xb.T.dot(dz1)
        db1 = dz1.sum(axis=0)
        dense_out.weights -= lr * dW4
        dense_out.biases -= lr * db4
        dense_hidden2.weights -= lr * dW3
        dense_hidden2.biases -= lr * db3
        dense_hidden1.weights -= lr * dW2
        dense_hidden1.biases -= lr * db2
        dense_in.weights -= lr * dW1
        dense_in.biases -= lr * db1

    dense_in.forward(X)
    activation_in.forward(dense_in.output)
    dense_hidden1.forward(activation_in.output)
    activation_hidden1.forward(dense_hidden1.output)
    dense_hidden2.forward(activation_hidden1.output)
    activation_hidden2.forward(dense_hidden2.output)
    dense_out.forward(activation_hidden2.output)
    activation_out.forward(dense_out.output)
    
    loss = loss_function.calculate(activation_out.output,y)
    losses.append(loss)
    
    predictions = np.argmax(activation_out.output, axis=1)
    accuracy = np.mean(predictions==y)
    accuracies.append(accuracy)

plt.figure()
plt.plot(losses, color="red")
plt.title("Neural Network — Loss")
plt.xlabel("Epoch")
plt.grid(True)
plt.show()

plt.figure()
plt.plot(accuracies, color="green")
plt.title("Neural Network — Accuracy")
plt.xlabel("Epoch")
plt.grid(True)
plt.show()

test_X, test_y = spiral_data(samples=450,classes=3)
xx, yy = np.meshgrid(
    np.linspace(test_X[:, 0].min() - 1, test_X[:, 0].max() + 1, 300),
    np.linspace(test_X[:, 1].min() - 1, test_X[:, 1].max() + 1, 300)
)
grid = np.c_[xx.ravel(), yy.ravel()]
dense_in.forward(grid)
activation_in.forward(dense_in.output)
dense_hidden1.forward(activation_in.output)
activation_hidden1.forward(dense_hidden1.output)
dense_hidden2.forward(activation_hidden1.output)
activation_hidden2.forward(dense_hidden2.output)
dense_out.forward(activation_hidden2.output)
activation_out.forward(dense_out.output)
activation_array = np.array(activation_out.output)
pred = np.argmax(activation_array,axis=1).reshape(xx.shape)
plt.figure()
plt.contourf(xx, yy, pred, 3)
plt.scatter(test_X[:, 0], test_X[:, 1], c=test_y, edgecolor="black")
plt.title("Neural Network — Decision Regions")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
# Out:
# (2, 32) (1, 32) (32, 3) (1, 3)
